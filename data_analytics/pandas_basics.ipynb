# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('incidents_small.csv')
df
# Out:
# /var/folders/ls/1wzc9b2x0238zs7fk2nzfbpm0000gn/T/ipykernel_2026/3532890934.py:1: DtypeWarning:
#
# Columns (1,2,3,4,5,6,7,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#          IncidntNum      Category  \
# 0       120058272.0   WEAPON LAWS
# 1       120058272.0   WEAPON LAWS
# 2       141059263.0      WARRANTS
# 3       160013662.0  NON-CRIMINAL
# 4       160002740.0  NON-CRIMINAL
# ...             ...           ...
# 150495          NaN           NaN
# 150496          NaN           NaN
# 150497          NaN           NaN
# 150498          NaN           NaN
# 150499          NaN           NaN
#
#                                               Descript DayOfWeek  \
# 0                            POSS OF PROHIBITED WEAPON    Friday
# 1       FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                       WARRANT ARREST    Monday
# 3                                        LOST PROPERTY   Tuesday
# ...

# %%
df = pd.read_csv('incidents_small.csv',parse_dates=['Date'])
df
# Out:
# /var/folders/ls/1wzc9b2x0238zs7fk2nzfbpm0000gn/T/ipykernel_2026/3580264055.py:1: DtypeWarning:
#
# Columns (1,2,3,5,6,7,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#          IncidntNum      Category  \
# 0       120058272.0   WEAPON LAWS
# 1       120058272.0   WEAPON LAWS
# 2       141059263.0      WARRANTS
# 3       160013662.0  NON-CRIMINAL
# 4       160002740.0  NON-CRIMINAL
# ...             ...           ...
# 150495          NaN           NaN
# 150496          NaN           NaN
# 150497          NaN           NaN
# 150498          NaN           NaN
# 150499          NaN           NaN
#
#                                               Descript DayOfWeek       Date  \
# 0                            POSS OF PROHIBITED WEAPON    Friday 2016-01-29
# 1       FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday 2016-01-29
# 2                                       WARRANT ARREST    Monday 2016-04-25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IncidntNum  10019 non-null  float64
#  1   Category    10019 non-null  object
#  2   Descript    10019 non-null  object
#  3   DayOfWeek   10019 non-null  object
#  4   Date        10019 non-null  datetime64[ns]
#  5   Time        10019 non-null  object
#  6   PdDistrict  10019 non-null  object
#  7   Resolution  10019 non-null  object
#  8   Address     10019 non-null  object
#  9   X           10019 non-null  float64
#  10  Y           10019 non-null  float64
#  11  Location    10019 non-null  object
#  12  PdId        10019 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 14.9+ MB

# %%
df.sort_values(by='IncidntNum', ascending = False, inplace=True)
df.head(30)
# Out:
#        IncidntNum        Category  \
# 9554  160939676.0         ASSAULT
# 9986  160895846.0  OTHER OFFENSES
# 9964  160893652.0    NON-CRIMINAL
# 9963  160893464.0     WEAPON LAWS
# 9962  160893395.0         ASSAULT
# 9953  160892842.0  SUSPICIOUS OCC
# 9952  160892836.0   LARCENY/THEFT
# 9951  160892820.0         ASSAULT
# 9950  160892814.0  OTHER OFFENSES
# 9945  160892591.0         ASSAULT
# 9944  160892585.0       VANDALISM
# 9933  160891662.0         ASSAULT
# 9860  160889786.0        BURGLARY
# 9859  160889764.0  OTHER OFFENSES
# 9858  160889742.0  OTHER OFFENSES
# 9857  160889736.0        WARRANTS
# 9826  160887677.0         ASSAULT
# 9727  160884689.0   VEHICLE THEFT
# 9715  160883766.0     WEAPON LAWS
# 9714  160883750.0        BURGLARY
# 9711  160883255.0   LARCENY/THEFT
# 9710  160883249.0       VANDALISM
# 9644  160880427.0  OTHER OFFENSES
# 9645  160880427.0       VANDALISM
# 9611  160877424.0       VANDALISM
# 9603  160876642.0         ASSAULT
# ...

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (10019, 13)

# %%
df.sort_values(by='Category', ascending = True, inplace=True)
df.head(30)
# Out:
#        IncidntNum Category                                           Descript  \
# 5148  160623584.0    ARSON                                              ARSON
# 2457  160135288.0    ARSON                                 ARSON OF A VEHICLE
# 9653  160294163.0    ARSON                     ARSON OF A COMMERCIAL BUILDING
# 45    160010527.0    ARSON                     ARSON OF A COMMERCIAL BUILDING
# 7267  160257967.0    ARSON                     ARSON OF AN INHABITED DWELLING
# 9245  160248223.0    ARSON                                              ARSON
# 722   160352614.0    ARSON                                 ARSON OF A VEHICLE
# 723   160352614.0    ARSON                     ARSON OF A COMMERCIAL BUILDING
# 8195  160270903.0    ARSON                     ARSON OF AN INHABITED DWELLING
# 5467  160223560.0    ARSON                     ARSON OF AN INHABITED DWELLING
# 6514  160245564.0    ARSON                     ARSON OF AN INHABITED DWELLING
# ...

# %%
category_count = df.Category.value_counts().reset_index()
category_count.columns = ['Category','Case Count']
category_count
# Out:
#                        Category  Case Count
# 0                 LARCENY/THEFT        1566
# 1                OTHER OFFENSES        1476
# 2                  NON-CRIMINAL        1242
# 3                       ASSAULT        1075
# 4                      WARRANTS         555
# 5                 VEHICLE THEFT         529
# 6                     VANDALISM         475
# 7                      BURGLARY         458
# 8                SUSPICIOUS OCC         443
# 9                 DRUG/NARCOTIC         396
# 10               MISSING PERSON         364
# 11                      ROBBERY         268
# 12                        FRAUD         188
# 13                     TRESPASS         146
# 14              SECONDARY CODES         146
# 15                  WEAPON LAWS         141
# 16            RECOVERED VEHICLE          77
# 17       SEX OFFENSES, FORCIBLE          74
# 18                 PROSTITUTION          59
# 19              STOLEN PROPERTY          55
# ...

# %%
category_count['Case Count'].head().plot.pie(autopct='%1.f%%', x ='Category')
# Out:
# <AxesSubplot: ylabel='Case Count'>

# %%
category_count_top_10 = category_count.head(10)
px.pie(category_count_top_10,'Category','Case Count')

# %%
df.head(2)
# Out:
#        IncidntNum Category            Descript DayOfWeek       Date   Time  \
# 5148  160623584.0    ARSON               ARSON   Tuesday 2016-08-02  17:43
# 2457  160135288.0    ARSON  ARSON OF A VEHICLE    Monday 2016-02-15  11:35
#
#      PdDistrict Resolution                       Address           X  \
# 5148   SOUTHERN       NONE     100 Block of HAWTHORNE ST -122.397071
# 2457   SOUTHERN       NONE  200 Block of INTERSTATE80 HY -122.365565
#
#               Y                               Location          PdId
# 5148  37.784003  (37.7840030154412, -122.397071005597)  1.606240e+13
# 2457  37.809671  (37.8096707013239, -122.365565425353)  1.601350e+13

# %% [markdown]
# find the most common way of handling incidents by the PD,in SanFrancisco using visualization

# %%
incidents = df.Resolution.value_counts()
incidents
# Out:
# NONE                                      6390
# ARREST, BOOKED                            3356
# UNFOUNDED                                  159
# JUVENILE BOOKED                             56
# EXCEPTIONAL CLEARANCE                       28
# ARREST, CITED                               18
# CLEARED-CONTACT JUVENILE FOR MORE INFO       5
# LOCATED                                      3
# NOT PROSECUTED                               1
# JUVENILE DIVERTED                            1
# PSYCHOPATHIC CASE                            1
# COMPLAINANT REFUSES TO PROSECUTE             1
# Name: Resolution, dtype: int64

# %% [markdown]
# getting only november entries

# %%
weekday = df[df.Date.dt.weekday == 1].Category.value_counts().plot.bar()   #way of plotting data
weekday
# Out:
# <AxesSubplot: >

# %%
# group incident categories by month
month_wise_cases= df.groupby(df.Date.dt.month)['Category'].count().reset_index()
month_wise_cases_columns = ['Month','Case Count']
month_wise_cases
# Out:
#     Date  Category
# 0      1      2097
# 1      2      2387
# 2      3      3361
# 3      4      1334
# 4      5        82
# 5      6       111
# 6      7       149
# 7      8       160
# 8      9       138
# 9     10       182
# 10    11        13
# 11    12         5

# %%
def num_to_months(num):
    months=['january','february','march','april','may','jun','july','aug','sept','oct','nov','dec']
    return months[num-1]

# %%
month_wise_cases[Month] = month_wise_cases['Month'].apply(num_to_months)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
px.bar(month_wise_cases,'Month','Case Count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/tanushiyadav/Documents/python data science/data_analytics/pandas_basics.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tanushiyadav/Documents/python%20data%20science/data_analytics/pandas_basics.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> px.bar(month_wise_cases,'Month','Case Count')
#
# ...

# %%
df
# Out:
#        IncidntNum     Category  \
# 7267  160257967.0        ARSON
# 8808  160281712.0        ARSON
# 548   160042542.0        ARSON
# 8851  160140889.0        ARSON
# 7078  160229148.0        ARSON
# ...           ...          ...
# 5001  160654959.0  WEAPON LAWS
# 5000  160654959.0  WEAPON LAWS
# 5104  160216048.0  WEAPON LAWS
# 1347  160069734.0  WEAPON LAWS
# 3084  160547348.0  WEAPON LAWS
#
#                                                Descript  DayOfWeek       Date  \
# 7267                     ARSON OF AN INHABITED DWELLING     Monday 2016-03-28
# 8808                     ARSON OF AN INHABITED DWELLING   Thursday 2016-03-17
# 548                                  ARSON OF A VEHICLE     Friday 2016-01-15
# 8851                                 ARSON OF A VEHICLE  Wednesday 2016-02-17
# 7078                                 ARSON OF A VEHICLE     Friday 2016-03-18
# ...                                                 ...        ...        ...
# ...

# %% [markdown]
# ## pivot table

# %%
df.pivot_table(index='Category',columns='Resolution',values='IncidntNum',aggfunc='count')
# Out:
# Resolution                   ARREST, BOOKED  ARREST, CITED  \
# Category
# ARSON                                   6.0            NaN
# ASSAULT                               427.0            NaN
# BRIBERY                                 4.0            NaN
# BURGLARY                               79.0            NaN
# DISORDERLY CONDUCT                     18.0            NaN
# DRIVING UNDER THE INFLUENCE            29.0            NaN
# DRUG/NARCOTIC                         364.0            1.0
# DRUNKENNESS                            39.0            NaN
# EMBEZZLEMENT                            NaN            NaN
# EXTORTION                               NaN            NaN
# FAMILY OFFENSES                         2.0            NaN
# FORGERY/COUNTERFEITING                 13.0            NaN
# FRAUD                                  26.0            NaN
# GAMBLING                                1.0            NaN
# KIDNAPPING                             10.0            NaN
# ...

# %%
print(df.columns.to_list())
# Out:
# ['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId']

# %%
df.pivot_table(index='Category',columns='DayOfWeek',values='IncidntNum',aggfunc='count')
# Out:
# DayOfWeek                    Friday  Monday  Saturday  Sunday  Thursday  \
# Category
# ARSON                           7.0     4.0       3.0     5.0       5.0
# ASSAULT                       161.0   157.0     169.0   155.0     137.0
# BRIBERY                         2.0     1.0       2.0     3.0       NaN
# BURGLARY                       77.0    60.0      55.0    59.0      72.0
# DISORDERLY CONDUCT              3.0    13.0       5.0     3.0       5.0
# DRIVING UNDER THE INFLUENCE     6.0     2.0      13.0     3.0       7.0
# DRUG/NARCOTIC                  53.0    73.0      46.0    52.0      45.0
# DRUNKENNESS                     8.0     4.0      11.0     6.0      10.0
# EMBEZZLEMENT                    NaN     NaN       1.0     1.0       2.0
# EXTORTION                       1.0     2.0       NaN     2.0       NaN
# FAMILY OFFENSES                 1.0     NaN       NaN     1.0       2.0
# FORGERY/COUNTERFEITING          7.0     6.0       6.0     6.0       9.0
# ...

# %% [markdown]
# ## apply a function

# %%
df['Category'] = df['Category'].apply(lambda val : val.lower())
df.head()
# Out:
#        IncidntNum Category                        Descript DayOfWeek  \
# 5148  160623584.0    arson                           ARSON   Tuesday
# 2457  160135288.0    arson              ARSON OF A VEHICLE    Monday
# 9653  160294163.0    arson  ARSON OF A COMMERCIAL BUILDING    Sunday
# 45    160010527.0    arson  ARSON OF A COMMERCIAL BUILDING    Monday
# 7267  160257967.0    arson  ARSON OF AN INHABITED DWELLING    Monday
#
#            Date   Time  PdDistrict      Resolution  \
# 5148 2016-08-02  17:43    SOUTHERN            NONE
# 2457 2016-02-15  11:35    SOUTHERN            NONE
# 9653 2016-04-10  04:15  TENDERLOIN  ARREST, BOOKED
# 45   2016-01-04  20:08     MISSION            NONE
# 7267 2016-03-28  23:00  TENDERLOIN  ARREST, BOOKED
#
#                            Address           X          Y  \
# 5148     100 Block of HAWTHORNE ST -122.397071  37.784003
# 2457  200 Block of INTERSTATE80 HY -122.365565  37.809671
# 9653        200 Block of POWELL ST -122.408065  37.786902
# ...

# %%
df['Descript'] = df['Descript'].apply(lambda val : val.lower())
df.head()
# Out:
#        IncidntNum Category                        Descript DayOfWeek  \
# 5148  160623584.0    arson                           arson   Tuesday
# 2457  160135288.0    arson              arson of a vehicle    Monday
# 9653  160294163.0    arson  arson of a commercial building    Sunday
# 45    160010527.0    arson  arson of a commercial building    Monday
# 7267  160257967.0    arson  arson of an inhabited dwelling    Monday
#
#            Date   Time  PdDistrict      Resolution  \
# 5148 2016-08-02  17:43    SOUTHERN            NONE
# 2457 2016-02-15  11:35    SOUTHERN            NONE
# 9653 2016-04-10  04:15  TENDERLOIN  ARREST, BOOKED
# 45   2016-01-04  20:08     MISSION            NONE
# 7267 2016-03-28  23:00  TENDERLOIN  ARREST, BOOKED
#
#                            Address           X          Y  \
# 5148     100 Block of HAWTHORNE ST -122.397071  37.784003
# 2457  200 Block of INTERSTATE80 HY -122.365565  37.809671
# 9653        200 Block of POWELL ST -122.408065  37.786902
# ...

# %%
df['PdDistrict'] = df['PdDistrict'].apply(lambda val : val.lower())
df.head()
# Out:
#        IncidntNum Category                        Descript DayOfWeek  \
# 5148  160623584.0    arson                           arson   Tuesday
# 2457  160135288.0    arson              arson of a vehicle    Monday
# 9653  160294163.0    arson  arson of a commercial building    Sunday
# 45    160010527.0    arson  arson of a commercial building    Monday
# 7267  160257967.0    arson  arson of an inhabited dwelling    Monday
#
#            Date   Time  PdDistrict      Resolution  \
# 5148 2016-08-02  17:43    southern            NONE
# 2457 2016-02-15  11:35    southern            NONE
# 9653 2016-04-10  04:15  tenderloin  ARREST, BOOKED
# 45   2016-01-04  20:08     mission            NONE
# 7267 2016-03-28  23:00  tenderloin  ARREST, BOOKED
#
#                            Address           X          Y  \
# 5148     100 Block of HAWTHORNE ST -122.397071  37.784003
# 2457  200 Block of INTERSTATE80 HY -122.365565  37.809671
# 9653        200 Block of POWELL ST -122.408065  37.786902
# ...

# %%
df['Resolution'] = df['Resolution'].apply(lambda val : val.lower())
df.head()
# Out:
#        IncidntNum Category                        Descript DayOfWeek  \
# 5148  160623584.0    arson                           arson   Tuesday
# 2457  160135288.0    arson              arson of a vehicle    Monday
# 9653  160294163.0    arson  arson of a commercial building    Sunday
# 45    160010527.0    arson  arson of a commercial building    Monday
# 7267  160257967.0    arson  arson of an inhabited dwelling    Monday
#
#            Date   Time  PdDistrict      Resolution  \
# 5148 2016-08-02  17:43    southern            none
# 2457 2016-02-15  11:35    southern            none
# 9653 2016-04-10  04:15  tenderloin  arrest, booked
# 45   2016-01-04  20:08     mission            none
# 7267 2016-03-28  23:00  tenderloin  arrest, booked
#
#                            Address           X          Y  \
# 5148     100 Block of HAWTHORNE ST -122.397071  37.784003
# 2457  200 Block of INTERSTATE80 HY -122.365565  37.809671
# 9653        200 Block of POWELL ST -122.408065  37.786902
# ...

# %%
tips = px.data.tips()       #us restaurant tips dataset # it downloads the data and gives it to us
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.total_bill - tips.tip
# Out:
# 0      0.0
# 153    0.0
# 155    0.0
# 156    0.0
# 157    0.0
#       ...
# 85     0.0
# 86     0.0
# 87     0.0
# 88     0.0
# 243    0.0
# Length: 244, dtype: float64

# %% [markdown]
# ## adding a new column (augmentation)

# %%
tips['food_bill']= tips.total_bill - tips.tip
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  food_bill
# 0        1.01  1.01  Female     No  Sun  Dinner     2        0.0
# 1        1.66  1.66    Male     No  Sun  Dinner     3        0.0
# 2        3.50  3.50    Male     No  Sun  Dinner     3        0.0
# 3        3.31  3.31    Male     No  Sun  Dinner     2        0.0
# 4        3.61  3.61  Female     No  Sun  Dinner     4        0.0

# %%
tips.sort_values(by='food_bill',ascending= False,inplace = True)
tips.head(2)
# Out:
#      total_bill   tip     sex smoker  day    time  size  food_bill
# 0          1.01  1.01  Female     No  Sun  Dinner     2        0.0
# 153        2.00  2.00    Male     No  Sun  Dinner     4        0.0

# %%
tips.pivot_table(index='day',columns='sex',values='food_bill',aggfunc=['max','min'])
# Out:
#         max         min
# sex  Female Male Female Male
# day
# Fri     0.0  0.0    0.0  0.0
# Sat     0.0  0.0    0.0  0.0
# Sun     0.0  0.0    0.0  0.0
# Thur    0.0  0.0    0.0  0.0

# %% [markdown]
# ##  general syntax for plotly express
# ...
# px.func(dataframe,colname,colname2,othersettings)

# %%
px
# Out:
# <module 'plotly.express' from '/Users/tanushiyadav/opt/miniconda3/lib/python3.9/site-packages/plotly/express/__init__.py'>

# %%
px.box(tips,'total_bill')

# %%
px.bar(tips.head(10),['total_bill','food_bill'])

# %%
px.box(tips,'total_bill',color='sex')

# %%
px.box(tips,'total_bill',color='smoker')

# %%
px.box(tips,'total_bill',color='tip')

# %%
px.violin(tips,'tip',color='sex')

# %%
px.scatter(tips,'total_bill','tip',color='sex',facet_col='day')

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
df.country.unique()  #non repeating values
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
dfc = df[df.country =='India']

# %%
px.bar(dfc,'year','lifeExp')

# %%
dfa = df[df.country == 'Albania']

# %%
px.funnel(dfa,'year','gdpPercap',title = 'Albanias gdp')

# %%
px.scatter_3d(df, x = 'year', y = 'lifeExp', z = 'pop',hover_data=['country'],size='pop',color='continent')

# %%
px.scatter(df,y='gdpPercap', x = 'lifeExp',
             hover_data=['country'],color='continent',size= 'pop',
             animation_frame='year',animation_group='country')

# %%
px.scatter(df,y='gdpPercap', x = 'lifeExp',
             hover_data=['continent'],color='continent',size= 'pop',
             animation_frame='year',animation_group='country')

# %%
continent = df.groupby('continent').mean()
continent
# Out:
# /var/folders/ls/1wzc9b2x0238zs7fk2nzfbpm0000gn/T/ipykernel_2026/3061899731.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#              year    lifeExp           pop     gdpPercap     iso_num
# continent
# Africa     1979.5  48.865330  9.916003e+06   2193.754578  458.826923
# Americas   1979.5  64.658737  2.450479e+07   7136.110356  393.720000
# Asia       1979.5  60.064903  7.703872e+07   7902.150428  404.666667
# Europe     1979.5  71.903686  1.716976e+07  14469.475533  427.633333
# Oceania    1979.5  74.326208  8.874672e+06  18621.609223  295.000000

# %%
px.sunburst(df,path=['continent','country','year'],values='pop')

# %%
px.icicle(df,path=['continent','country','year'],values='pop')
